# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from joblib import load

from helper import *

# %%
showings = load('../data/showings_extra_feature.joblib')
showings.replace(np.inf, 0, inplace=True)

# %% [markdown]
# # Coverage per hour

# %%
stats = dict()
for i in range(24):
    time = '0' + str(i) + ':00-0' + str(i) + ':59' if i<10 else str(i) + ':00-' + str(i) + ':59'
    stats[time] = showings.loc[showings.hour == i, 'coverage']
# Out:
# Wall time: 67.8 ms

# %%
bar_plot(stats, file_name='coverage_by_hour', w=20, h=7)
