# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import calendar
import numpy as np
import pandas as pd
from joblib import load

from helper import *

# %%
showings = load('../data/showings_extra_feature.joblib')
showings.replace(np.inf, 0, inplace=True)
genres = load('../data/genres.joblib')

# %%
week_of_release = showings.loc[showings.days_since_release < 10, ('dayofweek', 'tmdb_vote_average', 'year', 'coverage')]

# %% [markdown]
# # Coverage by TMDb score for the week following the release

# %%
scores = week_of_release.tmdb_vote_average.unique()
scores.sort()

# %%
stats = dict()
for i in scores:
    stats[i] = week_of_release.loc[week_of_release.tmdb_vote_average == i, 'coverage']

# %%
bar_plot(stats, w=20, h=7, min_cnt=2000)
