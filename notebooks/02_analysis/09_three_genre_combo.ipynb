# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import calendar
import numpy as np
import pandas as pd
from joblib import load

from helper import *

# %%
showings = load('../data/showings_extra_feature.joblib')
showings.replace(np.inf, 0, inplace=True)
genres = load('../data/genres.joblib')

# %% [markdown]
# # Coverage by three genre combo

# %%
# %%time
all_genres = showings.tmdb_genre_ids.tolist()
all_genre_tuples = set(tuple(np.sort(i)) for i in all_genres if len(i) > 1)
all_combos = [(i, j, k) for k in list(genres.keys()) for j in list(genres.keys()) for i in list(genres.keys()) if i < j < k]

genre_combo = list()
for i in all_combos:
    for j in all_genre_tuples:
        if i[0] in j and i[1] in j and i[2] in j:
            genre_combo.append(i)
            break
# Out:
# Wall time: 6.52 s

# %%
# %%time
stats = dict()
for i in genre_combo:
     stats[genres[i[0]] + '-' + genres[i[1]] + '-' + genres[i[2]]] = showings.loc[
        showings.tmdb_genre_ids.apply(lambda numbers: i[0] in numbers and i[1] in numbers and i[2] in numbers),
        'coverage']
# Out:
# Wall time: 1min 54s

# %%
delete = [i for i, j in stats.items() if j.count() < 1000]
for i in delete:
    del stats[i]

# %%
bar_plot(stats, r=270)
