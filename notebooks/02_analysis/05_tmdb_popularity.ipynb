# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import calendar
import numpy as np
import pandas as pd
from joblib import load

from helper import *

# %%
showings = load('../data/showings_extra_feature.joblib')
showings.replace(np.inf, 0, inplace=True)

# %% [markdown]
# # Coverage by TMDb popularity

# %%
popularity = list(set(showings.tmdb_popularity.unique().round()))
popularity.sort()

# %%
# %%time
stats = dict()
for i in popularity:
    stats[i] = showings.loc[showings.tmdb_popularity.round() == i, 'coverage']
# Out:
# Wall time: 4.33 s

# %%
bar_plot(stats, count=False, r=270, file_name='popularity', min_cnt=2000, d=0.6)
